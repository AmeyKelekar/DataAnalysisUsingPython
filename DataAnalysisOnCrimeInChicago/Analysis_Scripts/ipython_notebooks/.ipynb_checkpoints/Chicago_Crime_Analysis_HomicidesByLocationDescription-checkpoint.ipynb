# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from matplotlib.pyplot import show

# %%
crime_data = pd.read_csv('/Users/ameykelekar/Documents/DataAnalysisUsingPython/Data Analysis on Crime in Chicago/Chicago_crime/Crimes_-_2001_to_present.csv')

# %%
crime_data.head()
# Out:
#         ID Case Number                    Date                  Block  IUCR  \
# 0  6309193    HP390075  06/11/2008 11:00:00 PM        045XX W 87TH ST  4387
# 1  6309194    HP399120  06/16/2008 07:05:27 PM  010XX N MASSASOIT AVE  0810
# 2  6309195    HP383610  06/08/2008 10:50:00 PM   050XX S CAMPBELL AVE  0486
# 3  6309196    HP392398  06/13/2008 09:10:00 AM   076XX S CARPENTER ST  1310
# 4  6309197    HP398014  06/16/2008 08:50:00 AM    022XX W WARREN BLVD  0810
#
#       Primary Type                  Description Location Description Arrest  \
# 0    OTHER OFFENSE  VIOLATE ORDER OF PROTECTION            APARTMENT  False
# 1            THEFT                    OVER $500            RESIDENCE  False
# 2          BATTERY      DOMESTIC BATTERY SIMPLE            APARTMENT  False
# 3  CRIMINAL DAMAGE                  TO PROPERTY            RESIDENCE  False
# 4            THEFT                    OVER $500               STREET  False
#
#   Domestic              ...                Ward  Community Area  FBI Code  \
# 0     True              ...                18.0            70.0        26
# 1    False              ...                29.0            25.0        06
# 2     True              ...                14.0            63.0       08B
# 3    False              ...                17.0            71.0        14
# 4    False              ...                 2.0            28.0        06
#
#    X Coordinate Y Coordinate  Year              Updated On   Latitude  \
# 0     1147487.0    1846446.0  2008  02/04/2016 06:33:39 AM  41.734598
# 1     1137833.0    1906342.0  2008  02/04/2016 06:33:39 AM  41.899141
# 2     1160554.0    1871189.0  2008  02/04/2016 06:33:39 AM  41.802238
# 3     1170638.0    1854168.0  2008  02/04/2016 06:33:39 AM  41.755316
# 4     1161454.0    1900313.0  2008  02/04/2016 06:33:39 AM  41.882138
#
#    Longitude                       Location
# 0 -87.735264   (41.734598385, -87.73526384)
# 1 -87.769192  (41.899141429, -87.769191932)
# 2 -87.686710  (41.802237609, -87.686710161)
# 3 -87.650224  (41.755315836, -87.650223819)
# 4 -87.682600   (41.88213835, -87.682600206)
#
# [5 rows x 22 columns]

# %%
new_df= crime_data[crime_data['Primary Type'] == 'HOMICIDE']['Location Description'].value_counts().reset_index()

# %%
new_df
# Out:
#                         index  Location Description
# 0                      STREET                  3895
# 1                        AUTO                   985
# 2                   APARTMENT                   698
# 3                       ALLEY                   517
# 4                       HOUSE                   463
# 5                       PORCH                   247
# 6                        YARD                   164
# 7                 PARKING LOT                   139
# 8               PARK PROPERTY                    95
# 9                  VACANT LOT                    93
# 10                    HALLWAY                    79
# 11               RETAIL STORE                    67
# 12                    GANGWAY                    62
# 13                     GARAGE                    46
# 14    GAS STATION DRIVE/PROP.                    42
# 15                CHA GROUNDS                    38
# 16                 RESTAURANT                    37
# 17            CHA PARKING LOT                    35
# 18                CHA HALLWAY                    34
# 19                     TAVERN                    32
# 20                GAS STATION                    31
# 21                   BASEMENT                    29
# 22         ABANDONED BUILDING                    25
# 23              CHA APARTMENT                    24
# 24                  VESTIBULE                    16
# 25                      HOTEL                    15
# 26                       CLUB                    14
# 27                  STAIRWELL                    14
# 28                   DRIVEWAY                    13
# 29                     OFFICE                    13
# ..                        ...                   ...
# 58            CHURCH PROPERTY                     2
# 59         PUBLIC HIGH SCHOOL                     2
# 60                    PRAIRIE                     2
# 61               CHA ELEVATOR                     2
# 62        LIVERY STAND OFFICE                     2
# 63                    FACTORY                     2
# 64                 RIVER BANK                     2
# 65                       YMCA                     2
# 66              CTA "L" TRAIN                     2
# 67                COUNTY JAIL                     2
# 68          CURRENCY EXCHANGE                     2
# 69               CTA PROPERTY                     2
# 70          TRUCKING TERMINAL                     1
# 71  HOSPITAL BUILDING/GROUNDS                     1
# 72               BANQUET HALL                     1
# 73               LOADING DOCK                     1
# 74        GOVERNMENT BUILDING                     1
# 75                   SIDEWALK                     1
# 76                   POOLROOM                     1
# 77      EXPRESSWAY EMBANKMENT                     1
# 78              ROOMING HOUSE                     1
# 79      PUBLIC GRAMMAR SCHOOL                     1
# 80                   ELEVATOR                     1
# 81                LIVERY AUTO                     1
# 82              BAR OR TAVERN                     1
# 83                  RESIDENCE                     1
# 84                       BANK                     1
# 85             FUNERAL PARLOR                     1
# 86     JUNK YARD/GARBAGE DUMP                     1
# 87        CLEANERS/LAUNDROMAT                     1
#
# [88 rows x 2 columns]

# %%
100*crime_data[crime_data['Primary Type'] == 'HOMICIDE']['Location Description'].value_counts()/len(crime_data[crime_data['Primary Type'] == 'HOMICIDE'])
# Out:
# STREET                       47.721147
# AUTO                         12.068121
# APARTMENT                     8.551826
# ALLEY                         6.334232
# HOUSE                         5.672629
# PORCH                         3.026219
# YARD                          2.009311
# PARKING LOT                   1.703014
# PARK PROPERTY                 1.163930
# VACANT LOT                    1.139427
# HALLWAY                       0.967900
# RETAIL STORE                  0.820877
# GANGWAY                       0.759618
# GARAGE                        0.563587
# GAS STATION DRIVE/PROP.       0.514580
# CHA GROUNDS                   0.465572
# RESTAURANT                    0.453320
# CHA PARKING LOT               0.428816
# CHA HALLWAY                   0.416565
# TAVERN                        0.392061
# GAS STATION                   0.379809
# BASEMENT                      0.355305
# ABANDONED BUILDING            0.306297
# CHA APARTMENT                 0.294046
# VESTIBULE                     0.196030
# HOTEL                         0.183778
# CLUB                          0.171527
# STAIRWELL                     0.171527
# DRIVEWAY                      0.159275
# OFFICE                        0.159275
#                                ...
# CHURCH PROPERTY               0.024504
# PUBLIC HIGH SCHOOL            0.024504
# PRAIRIE                       0.024504
# CHA ELEVATOR                  0.024504
# LIVERY STAND OFFICE           0.024504
# FACTORY                       0.024504
# RIVER BANK                    0.024504
# YMCA                          0.024504
# CTA "L" TRAIN                 0.024504
# COUNTY JAIL                   0.024504
# CURRENCY EXCHANGE             0.024504
# CTA PROPERTY                  0.024504
# TRUCKING TERMINAL             0.012252
# HOSPITAL BUILDING/GROUNDS     0.012252
# BANQUET HALL                  0.012252
# LOADING DOCK                  0.012252
# GOVERNMENT BUILDING           0.012252
# SIDEWALK                      0.012252
# POOLROOM                      0.012252
# EXPRESSWAY EMBANKMENT         0.012252
# ROOMING HOUSE                 0.012252
# PUBLIC GRAMMAR SCHOOL         0.012252
# ELEVATOR                      0.012252
# LIVERY AUTO                   0.012252
# BAR OR TAVERN                 0.012252
# RESIDENCE                     0.012252
# BANK                          0.012252
# FUNERAL PARLOR                0.012252
# JUNK YARD/GARBAGE DUMP        0.012252
# CLEANERS/LAUNDROMAT           0.012252
# Name: Location Description, dtype: float64

# %%
#Change your figure size to be (25,100)
plt.subplots(figsize=(25,100))
#Make backround while
sns.set_style('white')
#every bar should have same color - windows blue
ax = sns.barplot(x='Location Description',y='index',data= new_df,n_boot = 200, color='#3778bf')
#change font size of ticks and labels to make them look big(Don't use deafult font size)
ax.xaxis.get_label().set_fontsize(30)
ax.yaxis.get_label().set_fontsize(30)
ax.set_xbound(0,5000)
ax.tick_params(axis='x',which='major',labelsize=24)
ax.tick_params(axis='y',which='major',labelsize=24)
#change the tilte
ax.set_title('Homicides by location description: Jan 2001 - present')
ax.title.set_fontsize(36)
for p in ax.patches:
    output = str(p.get_width()) + ' | ' +  '%1.2f'%((100 * p.get_width())/len(crime_data[crime_data['Primary Type'] == 'HOMICIDE'])) + '%'
    ax.annotate(output,(p.get_width() * 1.005, p.get_y() + 0.5),fontsize=30)
#plt.savefig('Homicides_By_LocationDescription:Jan2001-Present.png',dpi=None, facecolor='w', edgecolor='w',
        #orientation='portrait', papertype=None, format=None,
        #transparent=False, bbox_inches=None, pad_inches=0.1,
        #frameon=None)
show()
